# %%
import os
import sys

import numpy as np

sys.path.append(r"C:\Users\zschende\OneDrive - Ilmatieteen laitos\Data\smrt")

# %%
# import smrt
# from smrt.atmosphere.simple_atmosphere import SimpleAtmosphere
from smrt import make_atmosphere, make_model, make_snowpack, make_soil, sensor_list
from smrt.core.globalconstants import PERMITTIVITY_OF_AIR

# %%
# CIMR as passive microwave sensor
sensor = sensor_list.cimr(channel=["18", "37"])  # add theta=[53, 55] for feeds

# %% [markdown]
# Transmissivity

# %%
def extract_configuration(transmissivity_map):
    keys = ["frequency", "polarization", "theta", "transmissivity"]

    configuration = dict()
    for k in keys:
        try:
            x = np.unique([transmissivity_map[ch][k] for ch in transmissivity_map])
            if len(x) == 1:
                x = x[0]
            configuration[k] = x
        except KeyError:
            continue

    return configuration

# %%
# TODO veg: make_atmosphere needs vol as input
# use frequency, polarization, theta from channel_map


# from smrt.core.layer import layer_properties
# @layer_properties("stem_volume", "ke")  # may not work, better use **kwargs like make_soil
def forest_transmissivity_cohen(frequency, theta, mode, stem_volume=50, ke=None):
    """Calculate one-way transmissivity for forest canopy.

    _extended_summary_
    transmissivity (considered equal to transmittance in this case)

    Args:
        frequency (_type_): _description_
        theta (_type_): _description_
        vol (_type_): Stem volume in m3/ha
        ke (_type_, optional): Extinction coefficient. Defaults to None.

    Returns:
        _type_: _description_
    """

    costheta = np.cos(theta)

    # frequency_dict = {"%02i" % (frequency): frequency for freq in np.atleast_1d(frequency)}

    # passive mode
    if mode == "P":
        polarization = ["V", "H"]

        if ke is None:
            if frequency < 17e9:
                ke = np.array([0, 0])  # negligible attenuation
            elif frequency > 17e9 and frequency < 20e9:
                ke = np.array([0.007, 0.010])
            elif frequency > 35e9 and frequency < 39e9:
                ke = np.array([0.011, 0.012])
            else:
                raise ValueError("Frequency not supported")

        if theta != np.deg2rad(50):
            ke = [k * np.cos(np.deg2rad(50)) for k in ke]

        transmissivity = np.exp((-ke * stem_volume) / costheta)

    # active mode not yet implemented
    elif mode == "A":
        pass

    transmissivity_map = {
        "%02i" % (frequency / 1e9) + pola: dict(
            frequency=frequency,
            polarization=pola,
            theta=np.rad2deg(theta),
            transmissivity=transmissivity[idpola],
        )
        for idpola, pola in enumerate(polarization)
    }

    return transmissivity_map, transmissivity

# %%
transmissivity_map, transmissivity = forest_transmissivity_cohen(
    frequency=sensor.frequency[1], theta=np.deg2rad(50), mode="P", stem_volume=10
)

# %%
transmissivity
# Out:
# array([0.84271233, 0.82970351])

# %%
transmissivity_map
# Out:
# {'36V': {'frequency': np.float64(36500000000.0),
#   'polarization': 'V',
#   'theta': np.float64(50.0),
#   'transmissivity': np.float64(0.842712333214737)},
#  '36H': {'frequency': np.float64(36500000000.0),
#   'polarization': 'H',
#   'theta': np.float64(50.0),
#   'transmissivity': np.float64(0.8297035097119744)}}

# %%
extract_configuration(transmissivity_map)
# Out:
# {'frequency': np.float64(36500000000.0),
#  'polarization': array(['H', 'V'], dtype='<U1'),
#  'theta': np.float64(50.0),
#  'transmissivity': array([0.82970351, 0.84271233])}

# %% [markdown]
# Atmosphere

# %%
atmos_iso = make_atmosphere("simple_isotropic_atmosphere", tb_down=23, tb_up=23, transmittance=0.5)

# %%
atmos = make_atmosphere(
    "simple_atmosphere",
    theta=[0, 20, 40],
    tb_down={18.7e9: [23, 58, 64], 37e9: [10, 20, 30]},
    tb_up={18.7e9: [5, 10, 15], 37e9: [6, 7, 8]},
    transmittance={18.7e9: [1, 0.9], 37e9: [0.95, 0.85, 0.75]},
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:76, in SimpleAtmosphere.__init__(self, theta, tb_down, tb_up, transmittance)
#      75 try:
# ---> 76     self.trans = {
#      77         key: np.array(value)[i] for key, value in zip(transmittance.keys(), transmittance.values())
#      78     }
#      79 except IndexError:
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:77, in <dictcomp>(.0)
#      75 try:
#      76     self.trans = {
# ---> 77         key: np.array(value)[i] for key, value in zip(transmittance.keys(), transmittance.values())
#      78     }
#      79 except IndexError:
#
# IndexError: index 2 is out of bounds for axis 0 with size 2
#
# During handling of the above exception, another exception occurred:
#
# SMRTError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 atmos = make_atmosphere(
#       2     "simple_atmosphere",
#       3     theta=[0, 20, 40],
#       4     tb_down={18.7e9: [23, 58, 64], 37e9: [10, 20, 30]},
#       5     tb_up={18.7e9: [5, 10, 15], 37e9: [6, 7, 8]},
#       6     transmittance={18.7e9: [1, 0.9], 37e9: [0.95, 0.85, 0.75]},
#       7 )
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\inputs\make_medium.py:886, in make_atmosphere(atmosphere_model, **kwargs)
#     876     """Make a atmospheric single-layer using the prescribed atmosphere model.
#     877     Warning: this function is subject to change in the future when refactoring how SMRT deals with atmosphere.
#     878
#    (...)    881
#     882 """
#     884     atmosphere_class = import_class("atmosphere", atmosphere_model)
# --> 886     return atmosphere_class(**kwargs)
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:80, in SimpleAtmosphere.__init__(self, theta, tb_down, tb_up, transmittance)
#      76         self.trans = {
#      77             key: np.array(value)[i] for key, value in zip(transmittance.keys(), transmittance.values())
#      78         }
#      79     except IndexError:
# ---> 80         raise SMRTError(
#      81             "The length of the transmittance values must match the length of the theta array. "
#      82             f"Got {len(transmittance)} values for {len(theta)} angles."
#      83         )
#      84 else:
#      85     self.trans = np.array(transmittance)[i]
#
# SMRTError: The length of the transmittance values must match the length of the theta array. Got 2 values for 3 angles.

# %%
atmos.run(frequency=18e9, costheta=np.cos(np.deg2rad(50)), npol=2)
# Out:
# ---------------------------------------------------------------------------
# SMRTError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 atmos.run(frequency=18e9, costheta=np.cos(np.deg2rad(50)), npol=2)
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:77, in SimpleAtmosphere.run(self, frequency, costheta, npol)
#      73             x = x[frequency]
#      74     return np.repeat(np.interp(costheta, self.costheta, x), npol)
#      76 return AtmosphereResult(
# ---> 77     tb_down=interpolate(self.tbdown), tb_up=interpolate(self.tbup), transmittance=interpolate(self.trans)
#      78 )
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:71, in SimpleAtmosphere.run.<locals>.interpolate(x)
#      69 if isinstance(x, dict):
#      70     if frequency not in x.keys():
# ---> 71         raise SMRTError(f"Frequency {frequency} not found in atmosphere parameters.")
#      72     else:
#      73         x = x[frequency]
#
# SMRTError: Frequency 18000000000.0 not found in atmosphere parameters.

# %%
# Set frozen soil as substrate with values from Meloche et al. (2021)
epsr = 3.3
epsi = 0.0051
rms = 1.65e-2
tsoil = 270

sub = make_soil(
    "soil_wegmuller",
    permittivity_model=complex(epsr, epsi),
    roughness_rms=rms,
    temperature=tsoil,
)

# %%
# Set synthetic truth snowpack properties to obtain synthetic TB_obs
sp = make_snowpack(
    thickness=np.array([1]),
    microstructure_model="exponential",
    density=[300],
    temperature=[265],
    ice_permittivity_model=None,
    background_permittivity_model=PERMITTIVITY_OF_AIR,
    liquid_water=0,
    salinity=0,
    corr_length=[1 * 4 * (1 - 300 / 917) / 917 / 25],
    substrate=sub,
    atmosphere=atmos_iso,
)

# %%
# Initialize the SMRT model with IBA and DORT solver
smrt_model = make_model(
    "iba",
    "dort",
    rtsolver_options={
        "error_handling": "nan",
        "phase_normalization": True,
        "diagonalization_method": "shur_forcedtriu",
    },
)

# %%
# Synthetic TB observations
TB_obs = smrt_model.run(sensor, sp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Synthetic TB observations
# ----> 2 TB_obs = smrt_model.run(sensor, sp)
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\core\model.py:359, in Model.run(self, sensor, snowpack, atmosphere, snowpack_dimension, snowpack_column, progressbar, parallel_computation, runner)
#     356         runner = SequentialRunner(progressbar=progressbar)
#     358 #  run all the simulations (with atmosphere as long as it is not depreciated), the results is a flat list of results
# --> 359 results = runner(self.run_single_simulation, ((simul, atmosphere) for simul in simulations))
#     360 results = list(results)  # consume the generator if it is one
#     362 # reshape the results with successive concatenations
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\core\model.py:574, in SequentialRunner.__call__(self, function, argument_list)
#     565     return [
#     566         function(*args)
#     567         for args in tqdm(
#    (...)    571         )
#     572     ]
#     573 else:
# --> 574     return [function(*args) for args in argument_list]
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\core\model.py:574, in <listcomp>(.0)
#     565     return [
#     566         function(*args)
#     567         for args in tqdm(
#    (...)    571         )
#     572     ]
#     573 else:
# --> 574     return [function(*args) for args in argument_list]
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\core\model.py:537, in Model.run_single_simulation(self, simulation, atmosphere)
#     534     rtsolver = self.rtsolver
#     536 # run the rtsolver
# --> 537 result = rtsolver.solve(snowpack, emmodel_instances, sensor, snowpack.atmosphere or atmosphere)
#     539 return result
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\rtsolver\dort.py:160, in DORT.solve(self, snowpack, emmodels, sensor, atmosphere)
#     157     m_max = self.m_max
#     159 # solve the RT equation
# --> 160 outmu, intensity = self.dort(m_max=m_max)
#     162 # reshape the first dimension in two dimensions (theta, pola)
#     163 npol = len(pola)
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\rtsolver\dort.py:258, in DORT.dort(self, m_max, special_return)
#     250 streams = compute_stream(
#     251     self.n_max_stream, self.effective_permittivity, self.substrate_permittivity, mode=self.stream_mode
#     252 )
#     254 # TODO veg: prepare vegetation
#     255 # prepare the atmosphere
#     257 self.atmosphere_result = (
# --> 258     self.atmosphere.run(self.sensor.frequency, streams.outmu, npol) if self.atmosphere is not None else None
#     259 )
#     261 #
#     262 # compute the incident intensity array depending on the sensor
#     264 intensity_0, intensity_higher, incident_streams = self.prepare_intensity_array(
#     265     streams
#     266 )  # TODO Ghi: make an iterator
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:74, in SimpleAtmosphere.run(self, frequency, costheta, npol)
#      70         x = x[frequency]
#      71     return np.repeat(np.interp(costheta, self.costheta, x), npol)
#      73 return AtmosphereResult(
# ---> 74     tb_down=interpolate(self.tbdown), tb_up=interpolate(self.tbup), transmittance=interpolate(self.trans)
#      75 )
#
# File ~\OneDrive - Ilmatieteen laitos\Data\smrt\smrt\atmosphere\simple_atmosphere.py:70, in SimpleAtmosphere.run.<locals>.interpolate(x)
#      68 def interpolate(x):
#      69     if isinstance(x, dict):
# ---> 70         x = x[frequency]
#      71     return np.repeat(np.interp(costheta, self.costheta, x), npol)
#
# KeyError: np.float64(18700000000.0)

# %%
# no atmosphere
TB_obs.TbH()
# Out:
# <xarray.DataArray (frequency: 2)> Size: 16B
# array([250.61961632, 236.48431851])
# Coordinates:
#     theta         float64 8B 55.0
#     polarization  <U1 4B 'H'
#   * frequency     (frequency) float64 16B 1.87e+10 3.65e+10
# Attributes:
#     mode:     P

# %%
# no atmosphere
TB_obs.TbV()
# Out:
# <xarray.DataArray (frequency: 2)> Size: 16B
# array([265.68503605, 253.71498309])
# Coordinates:
#     theta         float64 8B 55.0
#     polarization  <U1 4B 'V'
#   * frequency     (frequency) float64 16B 1.87e+10 3.65e+10
# Attributes:
#     mode:     P

# %%
# simple atmosphere
TB_obs.TbH()
# Out:
# <xarray.DataArray (frequency: 2)> Size: 16B
# array([219.04767754, 187.8355027 ])
# Coordinates:
#     theta         float64 8B 55.0
#     polarization  <U1 4B 'H'
#   * frequency     (frequency) float64 16B 1.87e+10 3.65e+10
# Attributes:
#     mode:     P

# %%
# simple atmosphere
TB_obs.TbV()
# Out:
# <xarray.DataArray (frequency: 2)> Size: 16B
# array([228.24337575, 199.35822274])
# Coordinates:
#     theta         float64 8B 55.0
#     polarization  <U1 4B 'V'
#   * frequency     (frequency) float64 16B 1.87e+10 3.65e+10
# Attributes:
#     mode:     P
